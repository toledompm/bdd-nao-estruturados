# %% [markdown]
# **Usando a nova API da Câmara dos Deputados**
# ---------------------------
#
# Toda a documentação se encontra em [https://dadosabertos.camara.leg.br/swagger/api.html
#
# Vamos inicialmente mostrar o nome e identificador de cada deputado

# %%
import requests
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados'
resp = requests.get(url).json()
for d in resp['dados']:
    if d['siglaUf'] == 'RJ':
      print (d['nome'], d['id'], 
         d['siglaUf'], d['siglaPartido'])
# Out:
# Alessandro Molon 160511 RJ PSB
# Alexandre Serfiotis 178833 RJ PSD
# Altineu Côrtes 178937 RJ PL
# Aureo Ribeiro 160512 RJ SOLIDARIEDADE
# Benedita da Silva 73701 RJ PT
# Carlos Jordy 204460 RJ PSL
# Chico D'Angelo 141439 RJ PDT
# Chiquinho Brazão 204476 RJ AVANTE
# Chris Tonietto 204462 RJ PSL
# Christino Aureo 204440 RJ PP
# Clarissa Garotinho 178939 RJ PROS
# Daniel Silveira 204454 RJ PSL
# Daniela do Waguinho 204459 RJ MDB
# David Miranda 205548 RJ PSOL
# Delegado Antônio Furtado 204451 RJ PSL
# Dr. Luiz Antonio Teixeira Jr. 204450 RJ PP
# Felício Laterça 204477 RJ PSL
# Flordelis 204447 RJ PSD
# Gelson Azevedo 115746 RJ PL
# Glauber Braga 152605 RJ PSOL
# Gurgel 204442 RJ PSL
# Gutemberg Reis 204456 RJ MDB
# Helio Lopes 204444 RJ PSL
# Hugo Leal 141450 RJ PSD
# Jandira Feghali 74848 RJ PCdoB
# Jorge Braz 205550 RJ REPUBLICANOS
# Juninho do Pneu 204457 RJ DEM
# Lourival Gomes 196358 RJ PSL
# Luiz Antônio Corrêa 204448 RJ PL
# Luiz Lima 204455 RJ PSL
# Major Fabiana 204458 RJ PSL
# Marcelo Calero 204433 RJ CIDADANIA
# Marcelo Freixo 76874 RJ PSOL
# Márcio Labre 204452 RJ PSL
# Otoni de Paula 204441 RJ PSC
# Paulo Ganime 204461 RJ NOVO
# Paulo Ramos 133968 RJ PDT
# Pedro Paulo 122158 RJ DEM
# Professor Joziel 204446 RJ PSL
# Rodrigo Maia 74693 RJ DEM
# Rosangela Gomes 178945 RJ REPUBLICANOS
# Soraya Santos 178946 RJ PL
# Sóstenes Cavalcante 178947 RJ DEM
# Talíria Petrone 204464 RJ PSOL
# Vinicius Farah 204478 RJ MDB
# Wladimir Garotinho 204463 RJ PSD

# %% [markdown]
# **Exercício**
#
# Além do nome e identificador, mostre também o partido e UF de cada Deputado

# %%
import requests
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados'
resp = requests.get(url).json()
for d in resp['dados']:
  print (d['id'], d['nome'], d['siglaPartido'], d['siglaUf'])
# Out:
# 204554 Abílio Santana PL BA
# 204521 Abou Anni PSL SP
# 204379 Acácio Favacho PROS AP
# 204560 Adolfo Viana PSDB BA
# 204528 Adriana Ventura NOVO SP
# 121948 Adriano do Baldy PP GO
# 74646 Aécio Neves PSDB MG
# 141372 Aelton Freitas PL MG
# 160508 Afonso Florence PT BA
# 136811 Afonso Hamm PP RS
# 178835 Afonso Motta PDT RS
# 160527 Aguinaldo Ribeiro PP PB
# 204495 Airton Faleiro PT PA
# 204549 AJ Albuquerque PP CE
# 178836 Alan Rick DEM AC
# 160559 Alceu Moreira MDB RS
# 204413 Alcides Rodrigues PATRIOTA GO
# 204545 Alê Silva PSL MG
# 204501 Alencar Santana Braga PT SP
# 160511 Alessandro Molon PSB RJ
# 178972 Alex Manente CIDADANIA SP
# 204571 Alex Santana PDT BA
# 204544 Alexandre Frota PSDB SP
# 160545 Alexandre Leite DEM SP
# 204503 Alexandre Padilha PT SP
# 204516 Alexis Fonteyne NOVO SP
# 74057 Alice Portugal PCdoB BA
# 178927 Aliel Machado PSB PR
# 204353 Aline Gurgel REPUBLICANOS AP
# 204400 Aline Sleutjes PSL PR
# 178937 Altineu Côrtes PL RJ
# 178881 Aluisio Mendes PSC MA
# 204356 Amaro Neto REPUBLICANOS ES
# 178831 André Abdon PP AP
# 74471 André de Paula PSD PE
# 204423 André Ferreira PSC PE
# 133439 André Figueiredo PDT CE
# 178882 André Fufuca PP MA
# 204515 André Janones AVANTE MG
# 73696 Angela Amin PP SC
# 74212 Aníbal Gomes DEM CE
# 160553 Antonio Brito PSD BA
# 73433 Arlindo Chinaglia PT SP
# 141391 Arnaldo Jardim CIDADANIA SP
# 204414 Aroldo Martins REPUBLICANOS PR
# 160541 Arthur Lira PP AL
# 160600 Arthur Oliveira Maia DEM BA
# 74090 Átila Lins PP AM
# 74459 Átila Lira PP PI
# 160665 Augusto Coutinho SOLIDARIEDADE PE
# 204509 Áurea Carolina PSOL MG
# 160512 Aureo Ribeiro SOLIDARIEDADE RJ
# 69871 Bacelar PODE BA
# 178975 Baleia Rossi MDB SP
# 73701 Benedita da Silva PT RJ
# 109429 Benes Leocádio REPUBLICANOS RN
# 141335 Beto Faro PT PA
# 204358 Beto Pereira PSDB MS
# 178948 Beto Rosado PP RN
# 207176 Bia Cavassa PSDB MS
# 204374 Bia Kicis PSL DF
# 204388 Bibo Nunes PSL RS
# 141513 Bilac Pinto DEM MG
# 204561 Bira do Pindaré PSB MA
# 160538 Bohn Gass PT RS
# 74052 Bosco Costa PL SE
# 204551 Bosco Saraiva SOLIDARIEDADE AM
# 204502 Bozzella PSL SP
# 160589 Bruna Furlan PSDB SP
# 93083 Cacá Leão PP BA
# 204352 Camilo Capiberibe PSB AP
# 204572 Capitão Alberto Neto REPUBLICANOS AM
# 178829 Capitão Augusto PL SP
# 178924 Capitão Fábio Abreu PL PI
# 204487 Capitão Wagner PROS CE
# 213762 Carla Dickson PROS RN
# 204507 Carla Zambelli PSL SP
# 204361 Carlos Chiodini MDB SC
# 178962 Carlos Gomes REPUBLICANOS RS
# 178993 Carlos Henrique Gaguim DEM TO
# 204460 Carlos Jordy PSL RJ
# 74262 Carlos Sampaio PSDB SP
# 204426 Carlos Veras PT PE
# 141398 Carlos Zarattini PT SP
# 164360 Carmen Zanotto CIDADANIA SC
# 204369 Caroline de Toni PSL SC
# 204499 Cássio Andrade PSB PA
# 204380 Celina Leão PP DF
# 204370 Célio Moura PT TO
# 178876 Célio Silveira PSDB GO
# 204488 Célio Studart PV CE
# 141405 Celso Maldaner MDB SC
# 73441 Celso Russomanno REPUBLICANOS SP
# 204496 Celso Sabino PSL PA
# 204504 Cezinha de Madureira PSD SP
# 205476 Charles Fernandes PSD BA
# 204490 Charlles Evangelista PSL MG
# 141439 Chico D'Angelo PDT RJ
# 204476 Chiquinho Brazão AVANTE RJ
# 204462 Chris Tonietto PSL RJ
# 178928 Christiane de Souza Yared PL PR
# 204440 Christino Aureo PP RJ
# 178939 Clarissa Garotinho PROS RJ
# 74537 Claudio Cajado PP BA
# 141408 Cleber Verde REPUBLICANOS MA
# 204376 Coronel Armando PSL SC
# 204378 Coronel Chrisóstomo PSL RO
# 204514 Coronel Tadeu PSL SP
# 178963 Covatti Filho PP RS
# 135054 Cristiano Vale PL PA
# 204355 Da Vitoria CIDADANIA ES
# 141411 Dagoberto Nogueira PDT MS
# 74467 Damião Feliciano PDT PB
# 74060 Daniel Almeida PCdoB BA
# 178916 Daniel Coelho CIDADANIA PE
# 204367 Daniel Freitas PSL SC
# 204454 Daniel Silveira PSL RJ
# 204409 Daniel Trzeciak PSDB RS
# 204459 Daniela do Waguinho MDB RJ
# 160528 Danilo Cabral PSB PE
# 62881 Danilo Forte PSDB CE
# 116379 Darci de Matos PSD SC
# 205548 David Miranda PSOL RJ
# 204511 David Soares DEM SP
# 204451 Delegado Antônio Furtado PSL RJ
# 178908 Delegado Éder Mauro PSD PA
# 204512 Delegado Marcelo Freitas PSL MG
# 204569 Delegado Pablo PSL AM
# 164359 Delegado Waldir PSL GO
# 204542 Denis Bezerra PSB CE
# 160588 Diego Andrade PSD MG
# 178929 Diego Garcia PODE PR
# 160599 Dimas Fabiano PP MG
# 143632 Domingos Neto PSD CE
# 160758 Domingos Sávio PSDB MG
# 204518 Dr. Frederico PATRIOTA MG
# 204481 Dr. Jaziel PL CE
# 204439 Dr. Leonardo SOLIDARIEDADE MT
# 204450 Dr. Luiz Antonio Teixeira Jr. PP RJ
# 204351 Dr. Luiz Ovando PSL MS
# 204412 Dr. Zacharias Calil DEM GO
# 81297 Dra. Soraya Manato PSL ES
# 204434 Dra. Vanda Milani SOLIDARIEDADE AC
# 178994 Dulce Miranda MDB TO
# 204562 Edilázio Júnior PSD MA
# 141417 Edio Lopes PL RR
# 204421 Edna Henrique PSDB PB
# 74655 Eduardo Barbosa PSDB MG
# 204541 Eduardo Bismarck PDT CE
# 92346 Eduardo Bolsonaro PSL SP
# 204500 Eduardo Costa PTB PA
# 178977 Eduardo Cury PSDB SP
# 141421 Eduardo da Fonte PP PE
# 141422 Efraim Filho DEM PB
# 74075 Elcione Barbalho MDB PA
# 204364 Eli Borges SOLIDARIEDADE TO
# 160532 Eli Corrêa Filho DEM SP
# 204389 Elias Vaz PSB GO
# 178854 Elmar Nascimento DEM BA
# 198783 Emanuel Pinheiro Neto PTB MT
# 161550 Emidinho Madeira PSB MG
# 132504 Enio Verri PT PR
# 204537 Enrico Misasi PV SP
# 160575 Erika Kokay PT DF
# 160640 Eros Biondini PROS MG
# 204482 Euclydes Pettersen PSC MG
# 178871 Evair Vieira de Melo PP ES
# 178953 Expedito Netto PSD RO
# 68720 Fábio Henrique PDT SE
# 178969 Fábio Mitidieri PSD SE
# 141427 Fábio Ramalho MDB MG
# 171623 Fabio Reis MDB SE
# 204368 Fabio Schiochet PSL SC
# 160587 Fábio Trad PSD MS
# 66828 Fausto Pinato PP SP
# 204477 Felício Laterça PSL RJ
# 72442 Felipe Carreras PSB PE
# 204398 Felipe Francischini PSL PR
# 204371 Felipe Rigoni PSB ES
# 160666 Félix Mendonça Júnior PDT BA
# 204407 Fernanda Melchionna PSOL RS
# 141431 Fernando Coelho Filho DEM PE
# 92699 Fernando Monteiro PP PE
# 204427 Fernando Rodolfo PL PE
# 204411 Filipe Barros PSL PR
# 160598 Flávia Morais PDT GO
# 141434 Flaviano Melo MDB AC
# 191923 Flávio Nogueira PDT PI
# 204392 Francisco Jr. PSD GO
# 204510 Franco Cartafina PP MG
# 204494 Fred Costa PATRIOTA MG
# 204393 Frei Anastacio Ribeiro PT PB
# 74200 Gastão Vieira PROS MA
# 115746 Gelson Azevedo PL RJ
# 160669 Genecias Noronha SOLIDARIEDADE CE
# 204473 General Girão PSL RN
# 204484 General Peternelli PSL SP
# 204527 Geninho Zuliani DEM SP
# 178966 Geovania de Sá PSDB SC
# 204394 Gervásio Maia PSB PB
# 74383 Giacobo PL PR
# 204575 Gil Cutrim REPUBLICANOS MA
# 204491 Gilberto Abramo REPUBLICANOS MG
# 74270 Gilberto Nascimento PSC SP
# 204365 Gilson Marques NOVO SC
# 160673 Giovani Cherini PL RS
# 178996 Giovani Feltes MDB RS
# 152605 Glauber Braga PSOL RJ
# 204419 Glaustin da Fokus PSC GO
# 107283 Gleisi Hoffmann PT PR
# 74419 Gonzaga Patriota PSB PE
# 198197 Greyce Elias AVANTE MG
# 204513 Guiga Peixoto PSL SP
# 204531 Guilherme Derrite PP SP
# 160667 Guilherme Mussi PP SP
# 204442 Gurgel PSL RJ
# 73460 Gustavo Fruet PDT PR
# 204408 Gustinho Ribeiro SOLIDARIEDADE SE
# 204456 Gutemberg Reis MDB RJ
# 204465 Haroldo Cathedral PSD RR
# 204548 Heitor Freire PSL CE
# 178964 Heitor Schuch PSB RS
# 178873 Helder Salomão PT ES
# 204373 Hélio Costa REPUBLICANOS SC
# 178909 Hélio Leite DEM PA
# 204444 Helio Lopes PSL RJ
# 217036 Henrique do Paraíso REPUBLICANOS SP
# 73482 Henrique Fontana PT RS
# 204539 Hercílio Coelho Diniz MDB MG
# 178981 Herculano Passos MDB SP
# 73772 Hermes Parcianello MDB PR
# 178884 Hildo Rocha MDB MA
# 178959 Hiran Gonçalves PP RR
# 141450 Hugo Leal PSD RJ
# 160674 Hugo Motta REPUBLICANOS PB
# 204533 Idilvan Alencar PDT CE
# 204564 Igor Kannário DEM BA
# 204508 Igor Timo PODE MG
# 67138 Iracema Portella PP PI
# 204436 Isnaldo Bulhões Jr. MDB AL
# 73531 Ivan Valente PSOL SP
# 74848 Jandira Feghali PCdoB RJ
# 108338 Jaqueline Cassol PP RO
# 74273 Jefferson Campos PSB SP
# 160570 Jerônimo Goergen PP RS
# 178839 Jéssica Sales MDB AC
# 204435 Jesus Sérgio PDT AC
# 160531 Jhonatan de Jesus REPUBLICANOS RR
# 74366 João Campos REPUBLICANOS GO
# 141458 João Carlos Bacelar PL BA
# 178970 João Daniel PT SE
# 141459 João Maia PL RN
# 112437 João Marcelo Souza MDB MA
# 178910 Joaquim Passarinho PSD PA
# 204468 Joenia Wapichana REDE RR
# 204546 Joice Hasselmann PSL SP
# 217480 Jones Moura PSD RJ
# 205550 Jorge Braz REPUBLICANOS RJ
# 178857 Jorge Solla PT BA
# 141464 José Airton Félix Cirilo PT CE
# 141470 José Guimarães PT CE
# 204386 Jose Mario Schreiner DEM GO
# 204472 José Medeiros PODE MT
# 204391 José Nelto PODE GO
# 160619 José Nunes PSD BA
# 74079 José Priante MDB PA
# 204555 José Ricardo PT AM
# 74554 José Rocha PL BA
# 209189 Joseildo Ramos PT BA
# 204563 Josimar Maranhãozinho PL MA
# 215043 Josivaldo JP PODE MA
# 204474 Juarez Costa MDB MT
# 204420 Julian Lemos PSL PB
# 74317 Júlio Cesar PSD PI
# 204372 Julio Cesar Ribeiro REPUBLICANOS DF
# 73586 Júlio Delgado PSB MG
# 74253 Julio Lopes PP RJ
# 204520 Junio Amaral PSL MG
# 204497 Júnior Ferrari PSD PA
# 204574 Junior Lourenço PL MA
# 204550 Júnior Mano PL CE
# 178886 Juscelino Filho DEM MA
# 204536 Kim Kataguiri DEM SP
# 151208 Laercio Oliveira PP SE
# 141478 Laerte Bessa PL DF
# 98057 Lafayette de Andrada REPUBLICANOS MG
# 160534 Lauriete PSC ES
# 178832 Leandre PV PR
# 204375 Leda Sadala AVANTE AP
# 178825 LEO DE BRITO PT AC
# 204359 Léo Moraes PODE RO
# 204547 Léo Motta PSL MG
# 74156 Leonardo Monteiro PT MG
# 74254 Leonardo Picciani MDB RJ
# 74299 Leônidas Cristino PDT CE
# 92102 Leur Lomanto Júnior DEM BA
# 139285 Lídice da Mata PSB BA
# 74585 Lincoln Portela PL MG
# 204405 Liziane Bayer PSB RS
# 204382 Loester Trutis PSL MS
# 196358 Lourival Gomes PSL RJ
# 204523 Lucas Gonzalez NOVO MG
# 204404 Lucas Redecker PSDB RS
# 178879 Lucas Vergilio SOLIDARIEDADE GO
# 74478 Luciano Bivar PSL PE
# 178931 Luciano Ducci PSB PR
# 178954 Lucio Mosquini MDB RO
# 204381 Luis Miranda DEM DF
# 160510 Luis Tibé AVANTE MG
# 204410 Luisa Canziani PTB PR
# 204448 Luiz Antônio Corrêa PL RJ
# 204485 Luiz Carlos Motta PL SP
# 204455 Luiz Lima PSL RJ
# 162332 Luiz Nishimori PL PR
# 204526 Luiz Philippe de Orleans e Bragança PSL SP
# 74784 Luiza Erundina PSOL SP
# 204418 Luizão Goulart REPUBLICANOS PR
# 178866 Luizianne Lins PT CE
# 166402 Magda Mofatto PL GO
# 204458 Major Fabiana PSL RJ
# 204471 Mara Rocha PSDB AC
# 156190 Marcel van Hattem NOVO RS
# 179000 Marcelo Álvaro Antônio PSL MG
# 146788 Marcelo Aro PP MG
# 205863 Marcelo Brum PSL RS
# 76874 Marcelo Freixo PSB RJ
# 133810 Marcelo Moraes PTB RS
# 204558 Marcelo Nilo PSB BA
# 204556 Marcelo Ramos PL AM
# 178983 Marcio Alvino PL SP
# 179001 Márcio Biolchi MDB RS
# 204452 Márcio Labre PSL RJ
# 150418 Márcio Marinho REPUBLICANOS BA
# 204522 Marco Bertaiolli PSD SP
# 160535 Marcon PT RS
# 204431 Marcos Aurélio Sampaio MDB PI
# 204506 Marcos Pereira REPUBLICANOS SP
# 178943 Marcos Soares DEM RJ
# 204430 Margarete Coelho PP PI
# 74398 Maria do Rosário PT RS
# 204540 Maria Rosas REPUBLICANOS SP
# 178956 Mariana Carvalho PSDB RO
# 204428 Marília Arraes PT PE
# 204432 Marina Santos PL PI
# 74158 Mário Heringer PDT MG
# 178858 Mário Negromonte Jr. PP BA
# 204403 Marlon Santos PDT RS
# 204566 Marreca Filho PATRIOTA MA
# 178843 Marx Beltrão PSD AL
# 75431 Maurício Dziedricki PTB RS
# 74749 Mauro Lopes MDB MG
# 141508 Mauro Nazif PSB RO
# 188097 Merlong Solano PT PI
# 178985 Miguel Lombardi PL SP
# 92172 Milton Coelho PSB PE
# 178895 Misael Varella PSD MG
# 178997 Moses Rodrigues MDB CE
# 204453 Natália Bonavides PT RN
# 204449 Nelson Barbudo PSL MT
# 204415 Nereu Crispim PSL RS
# 146307 Neri Geller PP MT
# 74165 Neucimar Fraga PSD ES
# 178896 Newton Cardoso Jr MDB MG
# 204479 Nicoletti PSL RR
# 74352 Nilson Pinto PSDB PA
# 178986 Nilto Tatto PT SP
# 194260 Nivaldo Albuquerque PTB AL
# 66179 Norma Ayub DEM ES
# 74159 Odair Cunha PT MG
# 204498 Olival Marques DEM PA
# 178987 Orlando Silva PCdoB SP
# 204363 Osires Damaso PSC TO
# 73463 Osmar Serraglio PP PR
# 73692 Osmar Terra MDB RS
# 204422 Ossesio Silva REPUBLICANOS PE
# 141515 Otavio Leite PSDB RJ
# 204441 Otoni de Paula PSC RJ
# 204475 Ottaci Nascimento SOLIDARIEDADE RR
# 204573 Otto Alencar Filho PSD BA
# 160556 Padre João PT MG
# 160642 Pastor Eurico PATRIOTA PE
# 204570 Pastor Gil PL MA
# 204553 Pastor Sargento Isidório AVANTE BA
# 74160 Patrus Ananias PT MG
# 204377 Paula Belmonte CIDADANIA DF
# 171617 Paulão PT AL
# 141516 Paulo Abi-Ackel PSDB MG
# 178860 Paulo Azi DEM BA
# 204538 Paulo Bengtson PTB PA
# 193726 Paulo Eduardo Martins PSC PR
# 160558 Paulo Freire Costa PL SP
# 204461 Paulo Ganime NOVO RJ
# 204492 Paulo Guedes PT MG
# 74574 Paulo Magalhães PSD BA
# 141518 Paulo Pereira da Silva SOLIDARIEDADE SP
# 74400 Paulo Pimenta PT RS
# 133968 Paulo Ramos PDT RJ
# 141488 Paulo Teixeira PT SP
# 216544 Paulo Vicente Caleffi PSD RS
# 90201 Pedro Augusto Bezerra PTB CE
# 215045 Pedro Augusto Palareti PSD RJ
# 178912 Pedro Cunha Lima PSDB PB
# 217330 Pedro Dalua PSC AP
# 122974 Pedro Lucas Fernandes PTB MA
# 204395 Pedro Lupion DEM PR
# 160604 Pedro Uczai PT SC
# 178844 Pedro Vilela PSDB AL
# 204406 Pedro Westphalen PP RS
# 73943 Perpétua Almeida PCdoB AC
# 204524 Pinheirinho PP MG
# 204529 Policial Katia Sastre PL SP
# 73486 Pompeo de Mattos PDT RS
# 160601 Pr. Marco Feliciano PL SP
# 204390 Professor Alcides PP GO
# 204383 Professor Israel Batista PV DF
# 204446 Professor Joziel PSL RJ
# 204565 Professora Dayane Pimentel PSL BA
# 160639 Professora Dorinha Seabra Rezende DEM TO
# 160641 Professora Marcivania PCdoB AP
# 204467 Professora Rosa Neide PT MT
# 178951 Rafael Motta PSB RN
# 204567 Raimundo Costa PL BA
# 141523 Raul Henry MDB PE
# 74161 Reginaldo Lopes PT MG
# 205865 Reinhold Stephanes Junior PSD PR
# 178925 Rejane Dias PT PI
# 178989 Renata Abreu PODE SP
# 73801 Renildo Calheiros PCdoB PE
# 73788 Ricardo Barros PP PR
# 215042 Ricardo da Karol PSC RJ
# 204362 Ricardo Guidi PSD SC
# 160655 Ricardo Izar PP SP
# 213274 Ricardo Silva PSB SP
# 178920 Ricardo Teobaldo PODE PE
# 204489 Robério Monteiro PDT CE
# 152610 Roberto Alves REPUBLICANOS SP
# 160653 Roberto de Lucena PODE SP
# 204530 Rodrigo Agostinho PSB SP
# 204366 Rodrigo Coelho PSB SC
# 141531 Rodrigo de Castro PSDB MG
# 204480 Rogério Correia PT MG
# 160651 Rogério Peninha Mendonça MDB SC
# 178930 Roman PATRIOTA PR
# 178861 Ronaldo Carletto PP BA
# 204525 Rosana Valle PSB SP
# 178945 Rosangela Gomes REPUBLICANOS RJ
# 204357 Rose Modesto PSDB MS
# 178935 Rossoni PSDB PR
# 73466 Rubens Bueno CIDADANIA PR
# 74371 Rubens Otoni PT GO
# 178887 Rubens Pereira Júnior PCdoB MA
# 73604 Rui Falcão PT SP
# 160635 Ruy Carneiro PSDB PB
# 204535 Sâmia Bomfim PSOL SP
# 178990 Samuel Moreira PSDB SP
# 204416 Sanderson PSL RS
# 204387 Sargento Fahur PSD PR
# 178921 Sebastião Oliveira AVANTE PE
# 73808 Sérgio Brito PSD BA
# 178933 Sergio Souza MDB PR
# 204438 Sergio Toledo PL AL
# 204437 Severino Pessoa REPUBLICANOS AL
# 178961 Shéridan PSDB RR
# 204557 Sidney Leite PSD AM
# 74356 Silas Câmara REPUBLICANOS AM
# 204360 Silvia Cristina PDT RO
# 204425 Silvio Costa Filho REPUBLICANOS PE
# 178946 Soraya Santos PL RJ
# 178947 Sóstenes Cavalcante DEM RJ
# 92776 Stefano Aguiar PSD MG
# 177282 Subtenente Gonzaga PDT MG
# 204534 Tabata Amaral PDT SP
# 178922 Tadeu Alencar PSB PE
# 204464 Talíria Petrone PSOL RJ
# 206231 Ted Conti PSB ES
# 204466 Tereza Nelma PSDB AL
# 178862 Tia Eron REPUBLICANOS BA
# 143084 Tiago Dimas SOLIDARIEDADE TO
# 204519 Tiago Mitraud NOVO MG
# 160976 Tiririca PL SP
# 197438 Tito AVANTE BA
# 178934 Toninho Wandscheer PROS PR
# 157130 Túlio Gadêlha PDT PE
# 178863 Uldurico Junior PROS BA
# 195866 Vaidon Oliveira PROS CE
# 204385 Valdevan Noventa PL SE
# 160610 Valmir Assunção PT BA
# 141552 Valtenir Pereira MDB MT
# 74376 Vander Loubet PT MS
# 141553 Vanderlei Macris PSDB SP
# 204505 Vavá Martins REPUBLICANOS PA
# 204396 Vermelho PSD PR
# 74283 Vicentinho PT SP
# 137070 Vicentinho Júnior PL TO
# 204483 Vilson da Fetaemg PSB MG
# 141555 Vinicius Carvalho REPUBLICANOS SP
# 160591 Vinicius Gurgel PL AP
# 204532 Vinicius Poit NOVO SP
# 179587 Vitor Hugo PSL GO
# 178992 Vitor Lippi PSDB SP
# 215044 Vivi Reis PSOL PA
# 160569 Waldenor Pereira PT BA
# 178952 Walter Alves MDB RN
# 160518 Weliton Prado PROS MG
# 74043 Wellington Roberto PL PB
# 74044 Wilson Santiago PTB PB
# 74439 Wolney Queiroz PDT PE
# 191945 Zé Augusto Nalin DEM RJ
# 178889 Zé Carlos PT MA
# 204559 Zé Neto PT BA
# 160632 Zé Silva SOLIDARIEDADE MG
# 204517 Zé Vitor PL MG
# 160592 Zeca Dirceu PT PR

# %% [markdown]
# Na url da Câmara, no bloco dos Deputados, coloque **aplication/json** no Response Content Type. Você irá notar que existem mais informações que as descritas inicialmente. Por exemplo, vamos baixar todas as fotos, no diretório onde você iniciou o jupyter notebook, dos deputados de São Paulo. Aqui começamos a usar uma condição **if** sendo que o bloco de instruções será executado apenas quando aquela condição resultar True

# %%
import requests
url = 'https://dadosabertos.camara.leg.br/api/v2/deputados'
resp = requests.get(url).json()
for d in resp['dados']:
  if d['siglaPartido'] == 'PT':
    nome = d['nome'].lower()
    print (f'Gravando: {nome}')
    f = open(nome + '.jpg', 'wb')
    foto = requests.get(d['urlFoto']).content
    f.write(foto)
    f.close()
# Out:
# Gravando: afonso florence
# Gravando: airton faleiro
# Gravando: alencar santana braga
# Gravando: alexandre padilha
# Gravando: arlindo chinaglia
# Gravando: benedita da silva
# Gravando: beto faro
# Gravando: bohn gass
# Gravando: carlos veras
# Gravando: carlos zarattini
# Gravando: célio moura
# Gravando: enio verri
# Gravando: erika kokay
# Gravando: frei anastacio ribeiro
# Gravando: gleisi hoffmann
# Gravando: helder salomão
# Gravando: henrique fontana
# Gravando: joão daniel
# Gravando: jorge solla
# Gravando: josé airton félix cirilo
# Gravando: josé guimarães
# Gravando: josé ricardo
# Gravando: joseildo ramos
# Gravando: leo de brito
# Gravando: leonardo monteiro
# Gravando: luizianne lins
# Gravando: marcon
# Gravando: margarida salomão
# Gravando: maria do rosário
# Gravando: marília arraes
# Gravando: merlong solano
# Gravando: natália bonavides
# Gravando: nilto tatto
# Gravando: odair cunha
# Gravando: padre joão
# Gravando: patrus ananias
# Gravando: paulão
# Gravando: paulo guedes
# Gravando: paulo pimenta
# Gravando: paulo teixeira
# Gravando: pedro uczai
# Gravando: professora rosa neide
# Gravando: reginaldo lopes
# Gravando: rejane dias
# Gravando: rogério correia
# Gravando: rubens otoni
# Gravando: rui falcão
# Gravando: valmir assunção
# Gravando: vander loubet
# Gravando: vicentinho
# Gravando: waldenor pereira
# Gravando: zé carlos
# Gravando: zé neto
# Gravando: zeca dirceu

# %% [markdown]
# Note que o print tem uma string que começa com f. Quando fazemos isso, dentro da string, tudo o que aparece em chaves, é substituído pelo valor calculado

# %% [markdown]
# Vamos acessar o valor total gasto por um Deputado Federal, com sua quota parlamentar, registrado na API da Câmara. A Deputada Tábata Amaral tem identificador 204534. Usando o link de descrição da API verificamos que podemos fornecer mais de um ano. Fazendo testes, verificamos que o número máximo de itens é 100. Estas páginas irão aumentar ao longo do tempo. Verificamos novamente que, caso solicitada uma página maior, o item 'dado' volta vazio. Cada página tem uma URL de acesso, para seus itens. Existe um operador em Python, chamado range, que vai de um número até uma unidade a menos do segundo. Desta forma range(1, 100) nos gera o intervado de 1 até 99. No campo valorLiquido temos o gasto efetuado. Observe que a API nos retorna uma string, para poder somar, devemos converter o valor para float, antes de somar a uma variável total. Para imprimir com somente duas casas decimais, irei usar .2f
# Uma forma mais completa seria consultar o rótulo links, num primeiro acesso, e verificar a última página atual. Para simplificar este curso, para iniciantes, iremos fazer acessos desnecessários.

# %%
import requests
total = 0
for pag in range(1, 100):
  u = f'https://dadosabertos.camara.leg.br/api/v2/deputados/178939/despesas?ano=2019&ano=2020&ordem=ASC&ordenarPor=ano&pagina={pag}&itens=100'
  r = requests.get(u).json()
  for gasto in r['dados']:
    total = total + float(gasto['valorLiquido'])

print (f'Gasto em 2019 e 2020: R$ {total:.2f}')
# Out:
# Gasto em 2019 e 2020: R$ 355826.56

# %% [markdown]
# **Exercício**
#
# Calcule o valor gasto por outros Deputados Federais, substituindo o identificador

# %%
import requests
deputados = [
  {"id":204554, "nome": "Abílio Santana"},
  {"id": 204521, "nome": "Abou Anni"},
  {"id": 204379, "nome": "Acácio Favacho"},
]

for deputado in deputados:
  total = 0
  did = deputado["id"]
  dnome = deputado["nome"]
  for pag in range(1, 30):
    u = f'https://dadosabertos.camara.leg.br/api/v2/deputados/{did}/despesas?ano=2019&ano=2020&ordem=ASC&ordenarPor=ano&pagina={pag}&itens=100'
    r = requests.get(u).json()
    for gasto in r['dados']:
      total = total + float(gasto['valorLiquido'])
    
  print (f'{dnome} - Gasto em 2019 e 2020: R$ {total:.2f}')
# Out:
# Abílio Santana - Gasto em 2019 e 2020: R$ 895400.23

# %% [markdown]
# Outra análise interessante é saber quem são os fornecedores que mais receberam desta quota. Usamos um dicionário para guardar estes dados, se o fornecedor não está ainda na base, crio e inicializo com aquele valor, caso já exista somo com o total acumulado. Cada item de um dicionário é um par, quero colocar em ordem do segundo elemento, que referencio por um entre colchetes, lembre que o primeiro é zero. Abaixo os fornecedores da deputada Tábata Amaral em ordem descrescente de valor recebido acumulado, até o momento.

# %%
import requests
total = 0
fornecedores = {}
cnpjCpfFornecedores = {}
for pag in range(1, 100):
  u = f'https://dadosabertos.camara.leg.br/api/v2/deputados/178939/despesas?ano=2019&ano=2020&ordem=ASC&ordenarPor=ano&pagina={pag}&itens=100'
  r = requests.get(u).json()
  for gasto in r['dados']:
    valor = float(gasto['valorLiquido'])
    total = total + valor
    nome = gasto['nomeFornecedor']
    cnpjCpf = gasto['cnpjCpfFornecedor']
    if cnpjCpf not in cnpjCpfFornecedores:
      cnpjCpfFornecedores[cnpjCpf] = valor
      fornecedores[cnpjCpf] = nome
    else:
      cnpjCpfFornecedores[cnpjCpf] = cnpjCpfFornecedores[cnpjCpf] + valor

print (f'Total retornado API Câmara: R$ {total:.2f}')
def chave(f): return f[1]
maiores = sorted(cnpjCpfFornecedores.items(), key=chave, reverse=True)
for cnpjcpf, valor in maiores[:50]:
    print (cnpjcpf, fornecedores[cnpjcpf], f'R$ {valor:.2f}')
# Out:
# Total retornado API Câmara: R$ 355826.56
# 02012862000160 Cia Aérea - TAM R$ 203006.11
# 06928794000134 LGA Comunicação R$ 70000.00
# 12842700000102 OMEGA LOCADORA DE VEÍCULOS LTDA ME R$ 36000.00
# 05931710000159 Grupo Brasil DPE Design Producoes e Eventos LTDA R$ 10000.00
# 01079210004509 UNIDAS LOCADORA DE VEÍCULOS R$ 7943.44
# 27510280000134 LGA Analise e Conteudo LTDA R$ 7000.00
# 07575651000159 Cia Aérea - GOL R$ 3666.16
# 00000000000001 CELULAR FUNCIONAL R$ 3533.25
# 07319323000191 PANTANAL VEÍCULOS LTDA R$ 3200.00
# 02558157000162 Telefônia Brasil S/A - VIVO R$ 1518.15
# 01815580000138 TECNODIGITAL COMUNICACAO VISUAL LTDA R$ 978.00
# 08202116000115 AUTO POSTO AEROPORTO LTDA R$ 800.00
# 12132854000100 WMS COMERCIO DE ARTIGOS DE PAPELARIA LTDA-ME R$ 693.60
# 00306597003112 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 508.00
# 19156367000127 Gnz Comercio De Alimentos Eireli - Epp R$ 482.00
# 33469172001644 SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC R$ 463.15
# 04208323000126 GUSTAVO GONCALVES DE OLIVEIRA PAIVA R$ 461.95
# 00097626000400 BRASAL COMBUSTIVEIS LTDA R$ 350.00
# 36756435000108 FRED RESTAURANTE LTDA R$ 336.00
# 27402097000115 MIT COMERCIO DE ALIMENTOS LTDA R$ 315.26
# 05124620000156 GZ COMERCIO DE ALIMENTOS LTDA R$ 284.50
# 26713936000153 CESAR & MODESTO RESTAURANTE LTDA R$ 238.88
# 05124620000237 GZ COMERCIO DE ALIMENTOS LTDA EPP R$ 235.50
# 01323420000171 CANTINA DA MASSA EIRELI R$ 220.77
# 00000000000006 RAMAL R$ 211.94
# 00306597003546 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 200.00
# 00306597007614 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 200.00
# 33469172000672 SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC R$ 179.15
# 37130481000160 SAO JOAO POSTOS DE ABASTECIMENTO E SERVICOS LTDA R$ 170.00
# 13783221014690 MADERO INDUSTRIA E COMERCIO S. R$ 156.50
# 08414749000197 G3 Auto Posto Ltda Epp R$ 150.00
# 06071706000120 PETRONORTE COMBUSTIVEIS LTDA R$ 150.00
# 04473193000159 POSTO DA TORRE EIRELI - EPP R$ 150.00
# 33381724000181 POSTO DE LUBRIFICACAO SAO PEDRO LTDA R$ 145.03
# 39069299000842 TB COMERCIO DE ALIMENTOS LTDA R$ 103.00
# 04285663000150 AUTO POSTO DO NUCLEO LTDA R$ 100.00
# 30879261000194 AUTO POSTO GOLDEN GAS LAGO LTDA R$ 100.00
# 00306597002140 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 100.00
# 00306597007290 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 100.00
# 04711846000190 FLAMINGOCOMBUSTIVEIS E LUBRIFICANTES LTDA R$ 100.00
# 21017890000114 POSTO DE COMBUSTIVEL YASMIN LTDA R$ 100.00
# 10750039000180 POSTO DISBRAVE IMPERIAL LTDA R$ 100.00
# 31165607000155 ROTA 406 COMBUSTIVEIS LTDA R$ 100.00
# 02885153000199 POSTO DE COMBUSTIVEIS 311 NORTE LTDA R$ 90.00
# 16640472000149 QUATTRO RESTAURANTE COMERCIO DE ALIMENTOS E BEBID R$ 72.27
# 26645296000191 PARIS6 BRASILIA BISTRO E RESTAUR R$ 70.51
# 05000684000226 AUTO POSTO PETER PAN 01 LTDA R$ 70.00
# 14593102000172 JFZ BAR E RESTAURANTE LTDA - EPP R$ 65.90
# 17261661008662 OUTBACK STEAKHOUSE RESTAURANTES BRASIL S/A R$ 61.80
# 22304309000299 RESTAURANTE MADERO BRASILIA LT R$ 59.40

# %% [markdown]
# Observe que para totalizar corretamente temos que agrupar razões sociais.
#
# **Exercício**
#
# Verifique os maiores fornecedores de outros Deputados Federais

# %%
import requests
deputados = [
  {"id":204554, "nome": "Abílio Santana"},
  {"id": 204521, "nome": "Abou Anni"},
  {"id": 204379, "nome": "Acácio Favacho"},
]

for deputado in deputados:
  total = 0
  fornecedores = {}
  cnpjCpfFornecedores = {}

  did = deputado["id"]
  dnome = deputado["nome"]

  for pag in range(1, 30):
    u = f'https://dadosabertos.camara.leg.br/api/v2/deputados/{did}/despesas?ano=2019&ano=2020&ordem=ASC&ordenarPor=ano&pagina={pag}&itens=100'
    r = requests.get(u).json()
    for gasto in r['dados']:
      valor = float(gasto['valorLiquido'])
      total = total + valor
      nome = gasto['nomeFornecedor']
      cnpjCpf = gasto['cnpjCpfFornecedor']
      if cnpjCpf not in cnpjCpfFornecedores:
        cnpjCpfFornecedores[cnpjCpf] = valor
        fornecedores[cnpjCpf] = nome
      else:
        cnpjCpfFornecedores[cnpjCpf] = cnpjCpfFornecedores[cnpjCpf] + valor

  print (f'Total retornado API Câmara: R$ {total:.2f}')
  def chave(f): return f[1]
  maiores = sorted(cnpjCpfFornecedores.items(), key=chave, reverse=True)
  for cnpjcpf, valor in maiores[:50]:
      print (dnome, cnpjcpf, fornecedores[cnpjcpf], f'R$ {valor:.2f}')
# Out:
# Total retornado API Câmara: R$ 895400.23
# Abílio Santana 07319323000191 PANTANAL VEÍCULOS LTDA R$ 237207.00
# Abílio Santana 32348287000131 TAMIRYS MACHADO DOS SANTOS DE SANTANA R$ 105000.00
# Abílio Santana 33903780000139 CRISTIANE BARROS LOPES DE MENEZES SOCIEDADE INDIVIDUAL DE ADV R$ 83000.00
# Abílio Santana  GOL R$ 67828.00
# Abílio Santana 02012862000160 Cia Aérea - TAM R$ 61993.67
# Abílio Santana 07575651000159 GOL LINHAS AÉREAS INTELIGENTES R$ 57026.74
# Abílio Santana 04597810000128 GAJURE SERVICOS E COMERCIO LTDA R$ 50700.00
# Abílio Santana 06540941528 MATHEUS QUADROS LOIOLA MARTINS R$ 34100.00
# Abílio Santana 28068111000159 ONIX SERVIÇOS E ATIVIDADES DE CONSULTORIA EM GESTÃO EMPRESARIAL EIRELI - ME R$ 28000.00
# Abílio Santana 33378388000118 PAULAO COMUNICACOES E PROPAGANDAS EIRELI R$ 27000.00
# Abílio Santana 19998000000150 MARCELO BRUNER SOCIEDADE DE ADVOGADOS R$ 20000.00
# Abílio Santana 10522293000120 MAHMED & SANTIAGO REIS ADVOCACIA E CONSULTORIA R$ 16000.00
# Abílio Santana 14823830000123 DIARIO DA FEIRA ATIVIDADES DE COMUNICACAO LTDA - ME R$ 10000.00
# Abílio Santana 40575110000104 MICRO & SOFT INFORMATICA LTDA R$ 8960.00
# Abílio Santana 02575829000148 AVIANCA BRASIL R$ 6777.90
# Abílio Santana 04524416000240 JMF COMERCIO DE COMBUSTIVEIS LTDA - CABULA R$ 6226.74
# Abílio Santana 24951296000194 ECONOMIZE.COM LTDA - ME R$ 4400.00
# Abílio Santana 16168783000157 MONT FRIO REFRIGERAÇÃO LTDA R$ 4250.00
# Abílio Santana 04670324000198 M 55 COMERCIO DE COMBUSTIVEIS LTDA R$ 3495.37
# Abílio Santana 05532251000130 NOEL DA SILVA VELELA FILHO R$ 2550.00
# Abílio Santana 15139629000194 COMPANHIA DE ELETRICIDADE DO ESTADO DA BAHIA R$ 2203.63
# Abílio Santana 29056997000183 BEENLA NETWORKS LTDA R$ 2000.00
# Abílio Santana 33469172001644 SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC R$ 1804.14
# Abílio Santana 35802462000107 REJANE ALEANDRA PACHELA FERREIRA R$ 1800.00
# Abílio Santana 10348318000979 WINDSOR ADM. DE HOTEIS E SERVIÇOS LTDA R$ 1495.00
# Abílio Santana 12132854000100 WMS COMERCIO DE ARTIGOS DE PAPELARIA LTDA-ME R$ 1266.10
# Abílio Santana 00000000000007 CORREIOS - CARTA COMERCIAL R$ 1256.91
# Abílio Santana 30407533000153 POSTO DE COMBUSTIVEIS RODOVIARIA LTDA R$ 1231.65
# Abílio Santana 18938147000192 EWS ESTACIONAMENTOS SALVADOR S.A. R$ 1179.00
# Abílio Santana 02818012000404 HP COMERCIO E DERIVADOS DE PET R$ 1169.71
# Abílio Santana 09967852017283 Hotel Accor Brasil S/A R$ 1124.55
# Abílio Santana 09296295000160 Cia Aérea - AZUL R$ 1082.03
# Abílio Santana 08202116000115 AUTO POSTO AEROPORTO LTDA R$ 1079.63
# Abílio Santana 08600683000200 GRC COMERCIO DE COMBUSTIVEIS E DERIVADOS DE PETROLEO LTDA - R$ 1059.63
# Abílio Santana 00306597007614 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 1025.25
# Abílio Santana 14193173000188 MARIA BONITA COMERCIO DE COMBUSTIVEIS E LUBRIFICANTES LTDA R$ 926.50
# Abílio Santana 00187214000623 POSTO DE COMBUSTIVEIS JAGUARIB R$ 889.62
# Abílio Santana 32257816000191 BONJOUR COMERCIO DE COMBUSTIVEIS E LUBRIFICANTES LTDA R$ 740.00
# Abílio Santana 00031708000100 SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTORISTAS AUXILIARES DO DISTRITO FEDERAL R$ 732.00
# Abílio Santana 24543741000187 EDVALDO S SANTOS FILHO R$ 709.28
# Abílio Santana 13615307000149 POSTO ROSARIO LTDA R$ 672.48
# Abílio Santana 15151046002556 POSTO KALILANDIA LTDA R$ 622.60
# Abílio Santana 11322064000125 SOBRAL &amp; FILHOS COMERCIO DE COMBUSTIVEIS LTDA - PSG1 R$ 597.67
# Abílio Santana 16320541000137 SAO RAFAEL POSTOS DE SERVICOS LTDA R$ 564.56
# Abílio Santana 13503297000150 POSTO DE COMBUSTIVEIS CESARONI LTDA R$ 497.26
# Abílio Santana 14219216000157 COM.CARB. E LUB. ITAPARICA LTDA R$ 494.56
# Abílio Santana 14125832000149 POSTO MARATONA LTDA R$ 493.58
# Abílio Santana 30407524000162 POSTO DE COMBUSTIVEIS PORTAL DE SALVADOR LTDA R$ 485.16
# Abílio Santana 03223866000150 PARAISO DERIVADOS DE PETROLEO LTDA R$ 464.08
# Abílio Santana 15847874000156 SODIC SOCIEDADE REVENDEDORA DE COMBUSTIVEIS LTDA R$ 463.42
# Total retornado API Câmara: R$ 403702.58
# Abou Anni 00000000000007 CORREIOS - CARTA COMERCIAL R$ 111652.94
# Abou Anni 46395000000139 PREFEITURA DE SÃO PAULO R$ 83228.95
# Abou Anni 22238840000120 PERSONAL 7 PRODUTOS PROMOCIONAIS EIRELI R$ 45109.22
# Abou Anni 02012862000160 LATAM AIRLINES R$ 30211.39
# Abou Anni 16706383000158 FAGUNDES IMPRESSOS EM GERAL EIRELI R$ 22088.00
# Abou Anni 07575651000159 GOL LINHAS AÉREAS INTELIGENTES R$ 19612.31
# Abou Anni 02353246000172 JM ENVELOPES E ARTEFATOS DE PAPEL LTDA EPP R$ 14400.00
# Abou Anni 02558157000162 TELEFONIA BRASIL S.A. - VIVO R$ 10799.41
# Abou Anni 61695227000193 ELETROPAULO METROPOLITANA DE SÃO PAULO S/A R$ 8125.21
# Abou Anni 43776517000180 CIA DE SANEAMENTO BASICO DO ESTADO DE SAO PAULO SABESP R$ 3734.07
# Abou Anni 18033552000161 99 POP R$ 2771.44
# Abou Anni 02575829000148 AVIANCA BRASIL R$ 2252.92
# Abou Anni 07286731000194 SILT SELF SERVICE EIRELI R$ 2125.33
# Abou Anni 02710203000105 ROBSON DOMINGOS ALVES R$ 2089.14
# Abou Anni 43283811006867 KALUNGA COMERCIO E INDUSTRIA GRAFICA LTDA R$ 1902.90
# Abou Anni 09296295000160 AZUL LINHAS AÉREAS INTELIGENTES S.A R$ 1686.80
# Abou Anni 17895646000187 UBER DO BRASIL TECNOLOGIA LTDA R$ 1648.44
# Abou Anni 60961612000172 AUTO POSTO ORTEGA LTDA R$ 1501.20
# Abou Anni 13041197000159 OCEANO BLUE COMERCIO DE COMBUSTIVEIS LTDA R$ 1491.08
# Abou Anni 02646144000145 AUTO POSTO NOVO CENTRO LTDA R$ 1415.77
# Abou Anni 18811994000191 POSTO DE SERVICOS 23 DE MAIO LTDA R$ 1382.02
# Abou Anni 19367661000188 K2G SUPRIMENTOS DE IMPRESSAO E INFORMATICA EIRELLI R$ 1135.00
# Abou Anni 61457941000143 GOMAQ MÁQUINAS PARA ESCRITÓRIO LTDA R$ 1105.80
# Abou Anni 61357398000102 RESTAURANTE DOM LTDA R$ 892.70
# Abou Anni 34028316291329 ECT-EMP BRAS DE CORREIOS E TELEGRAFOS R$ 887.60
# Abou Anni 00306597007614 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 750.00
# Abou Anni 26368650000188 SB CHURRASCARIA LTDA R$ 700.62
# Abou Anni 26238785000129 MS PLASTPEL COMERCIO DE DESCARTÁVEIS LTDA ME R$ 677.40
# Abou Anni 01445847000142 COTOVIA GALETOS E MASSAS LTDA R$ 674.43
# Abou Anni 61990693000100 AUTO POSTO PIRAI LTDA R$ 664.00
# Abou Anni 23006986000102 OFL ESPIRONELLI DISTRIBUIDORA DE EMBALAGENS EPP R$ 580.60
# Abou Anni 09057642000100 JN RESTAURANTE MINEIRO LTDA R$ 536.89
# Abou Anni 61027223000137 MISTER PLUS AUTOMOTIVOS E CONVENIENCIAS LTDA ME R$ 534.51
# Abou Anni 26352131000121 H A REINA COMUNICAÇÃO VISUAL - ME R$ 495.00
# Abou Anni 00755990000330 TONER PRINT COM E MANUT DE EQUIP E PROD DE INFORM LTDA R$ 472.80
# Abou Anni 38010633000153 VIA. DF RENT A CAR R$ 468.00
# Abou Anni 43283811014614 Kalunga Comercio e Industria Grafica Ltda R$ 441.90
# Abou Anni 02451848000162 CONC. SISTEMA ANHANGUERA-BANDEIRANTES S/A R$ 438.80
# Abou Anni 05398233000108 JOSE ROBERTO AMATANGELO LUBRIFICANTES R$ 423.00
# Abou Anni 33469172001644 SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC R$ 420.31
# Abou Anni 33469172002292 SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC R$ 405.54
# Abou Anni 01266195000189 CENTRO AUTOMOTIVO INVICTO LT R$ 360.00
# Abou Anni 10140332000125 lanchonete java sucos e lanches ltda me R$ 357.11
# Abou Anni 08202116000115 AUTO POSTO AEROPORTO LTDA R$ 350.00
# Abou Anni 04473193000159 POSTO DA TORRE EIRELI - EPP R$ 350.00
# Abou Anni 10750039000180 POSTO DISBRAVE IMPERIAL LTDA R$ 350.00
# Abou Anni 16670649000150 G3 ALIMENTOS LTDA. R$ 334.71
# Abou Anni 00031708000100 SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTORISTAS AUXILIARES DO DISTRITO FEDERAL R$ 334.00
# Abou Anni 27745923000129 M21 AUTO POSTO E CONVENIENCIA LTDA R$ 300.05
# Abou Anni 43668946000133 AUTO POSTO LUPPI LTDA R$ 300.00
# Total retornado API Câmara: R$ 988662.72
# Acácio Favacho 23982484000117 TRAVEL TO AMAZON EIRELI - EPP R$ 362000.00
# Acácio Favacho 32634983000104 DISTRITTO ASSESSORIA CONTABIL LTDA R$ 100000.00
# Acácio Favacho 28234008000131 MASTERGRAF SERVICOS GRAFICOS EIRELI ME R$ 92256.10
# Acácio Favacho  AZUL R$ 77780.17
# Acácio Favacho 09489958000162 CP3 LTDA-ME R$ 57635.00
# Acácio Favacho 16878180000149 AUXILIAR CONTABIL ASSESSORIA EMPRESARIAL LTDA R$ 49700.00
# Acácio Favacho 15144822000113 E. VIEGAS FERREIRA EIRELI LTDA - LOCASERVICE R$ 49500.00
# Acácio Favacho 02012862000160 Latam Airlines R$ 43382.82
# Acácio Favacho 18621103000134 NATULINO BATISTA BASTOS MEI R$ 34000.00
# Acácio Favacho 33822440000183 HEKO TECH CONSULTORIA EMPRESARIAL LTDA R$ 25000.00
# Acácio Favacho 07575651000159 GOL LINHAS AEREAS S.A. R$ 13434.79
# Acácio Favacho 18827227000170 S NAFES M DA SILVA JUNIOR R$ 10000.00
# Acácio Favacho 00306597003112 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 8163.49
# Acácio Favacho 09296295000160 AZUL LINHAS AÉREAS INTELIGENTES S.A R$ 5813.08
# Acácio Favacho 12607854000110 ANDRADE E MACHADO LTDA EPPP R$ 5127.84
# Acácio Favacho 22209187000170 VN & FW LTDA-M R$ 5000.00
# Acácio Favacho 08884038000186 FRATELLI POSTO DE COMBUSTIVEIS LTDA R$ 4628.43
# Acácio Favacho 05018654000166 GM 3 LTDA ME R$ 4000.00
# Acácio Favacho 23068984000571 A C CAMBRAIA LTDA R$ 3600.00
# Acácio Favacho 00000000000001 CELULAR FUNCIONAL R$ 3476.55
# Acácio Favacho 17761648000183 LUCIANO BRUNO DE SOUZA GOES R$ 3000.00
# Acácio Favacho 22188950000124 WALDERNEY BARBOSA PANTALEÃO R$ 3000.00
# Acácio Favacho 45809753000261 AUGUSTA PARK HOTEIS LTDA R$ 2527.00
# Acácio Favacho 08116373000134 C.C.D. DE SOUZA R$ 2000.00
# Acácio Favacho 31180570000134 Lucas Paulino de Sousa Nogueira R$ 1840.30
# Acácio Favacho 00097626000672 BRASAL COMBUSTIVEIS LTDA R$ 1811.90
# Acácio Favacho 00000000000002 LINHA DIRETA R$ 1643.14
# Acácio Favacho 00290060000196 POSTO E RESTAURANTE SÃO PAULO LTDA R$ 1531.08
# Acácio Favacho 04621225000116 MM COMERCIAL DE COMBUSTIVEIS LTDA R$ 1425.00
# Acácio Favacho 32373812000179 EDVALDO FRANCISCO DE OLIVEIRA R$ 1211.00
# Acácio Favacho 11430412000340 3 VIAS COMERCIO DE DERIVADOS DE PETROLEO R$ 1101.96
# Acácio Favacho 04711846000190 FLAMINGOCOMBUSTIVEIS E LUBRIFICANTES LTDA R$ 1073.10
# Acácio Favacho 20411630000166 CAVALCANTE SANTOS LTDA - ME R$ 1000.00
# Acácio Favacho 00000000000007 CORREIOS - SEDEX CONVENCIONAL R$ 930.79
# Acácio Favacho 19257042000130 DRA 4 DERIVADOS DE PETROLEO LTDA R$ 836.41
# Acácio Favacho 00306597008181 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 740.04
# Acácio Favacho 15761498000182 MIGUEL AUTO POSTO LTDA R$ 326.05
# Acácio Favacho 00306597007614 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 310.07
# Acácio Favacho 05454390000193 GOES COMBUSTIVEIS LUBRIRICANTES E GLP LTDA R$ 254.05
# Acácio Favacho 21719469000155 M RIBEIRO COMBUSTIVEIS LTDA R$ 250.00
# Acácio Favacho 36180754000118 AUTO POSTO DE COMBUSTIVEL FLAMINGO LTDA R$ 240.94
# Acácio Favacho 01156523000194 JADE COM. DE DERIVADOS DE PETROLEO LTDA R$ 240.04
# Acácio Favacho 00001388000226 DISTRIBUIDORA BRASILIA DE VEICULOS S/A - POSTO DISBRAVE W3 R$ 240.03
# Acácio Favacho 00306597006995 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 240.01
# Acácio Favacho 00360990000179 POSTO DE GASOLINA DOS ANOES LTDA R$ 238.57
# Acácio Favacho 00641761000122 POSTO SAO ROQUE LTDA R$ 236.87
# Acácio Favacho 01304695000168 AUTO POSTO PAINEIRAS LTDA R$ 232.11
# Acácio Favacho 05807200000174 COMERCIAL DE SERVICOS UNIAO LTDA ME R$ 229.00
# Acácio Favacho 00306597001683 CASCOL COMBUSTIVEIS PARA VEICULOS LTDA R$ 225.01
# Acácio Favacho 00001388000307 DISTRIBUIDORA BRASILIA DE VEICULOS S/A - POSTO DISBRAVE SOBR R$ 225.00

# %% [markdown]
# Como podemos descobrir Dados de Deputados nas Legislaturas passadas? Por exemplo, do Deputado Jair Bolsonaro? Encontrando a Biografia do Deputado (https://www.camara.leg.br/deputados/74847/biografia), após pesquisar no Google, obtemos na URL o seu identificador. Como saber as Legislaturas? Pela biografia, sabemos as Datas de Início de sua atividade politica na Câmara, na API da Câmara chegamos que isso engloba as Legislaturas de 49 a 55. Na API podemos colocar os anos de 2016 a 2019. Podemos tentar trazer o máximo de itens por página, porém você irá descobrir, numa tentativa e erro, que o máximo é de 100 itens. No final do JSON de retorno, outra informação importante é de que temos páginas de 1 até 16, o que implica usar range(1, 17), pois range termina no número anterior ao segundo parâmetro fornecido. Pelo final do JSON retornado, você sabe como construir a requisição de cada página.

# %%
import requests
sair = 'o a à e os às as de da do ao na no nos nas não são nº em que com aos dos das pelo sobre por para pela entre contra'.split()
keywords = []
sumarios = []
for pag in range (1,17):
  url = f'https://dadosabertos.camara.leg.br/api/v2/deputados/74847/discursos?idLegislatura=49&idLegislatura=50&idLegislatura=51&idLegislatura=52&idLegislatura=53&idLegislatura=54&idLegislatura=55&dataInicio=1990-01-01&dataFim=2019-12-31&ordenarPor=dataHoraInicio&ordem=ASC&pagina={pag}&itens=100'
  resp = requests.get(url).json()
  for d in resp['dados']:
    s = d['sumario'].lower()
    s = ''.join(e for e in s if e not in ".,'()-")
    s = s.split()
    s = [w for w in s if w not in sair]
    sumarios.extend(s)
    if not d['keywords']: continue
    s = d['keywords'].lower()
    s = ''.join(e for e in s if e not in ".,'()-")
    s = s.split()
    s = [w for w in s if w not in sair]
    keywords.extend(s)

from collections import Counter
keywords = Counter(keywords)
sumarios = Counter(sumarios)
print (keywords.most_common(100))
print (sumarios.most_common(100))

# %% [markdown]
# Explicações: estamos removendo sinais especiais, split() quebra a string pelo espaço ou sinal de pular linha, split(',') separa por vírgula, a função extend faz algo parecido com append, enquanto append inclui um único elemento no final da lista, extend inclui vários. A função Counter vai contabilizar o número de vezes em que aparece um elemento na lista, criando um dicionário. No final vamos mostrar os 100 termos que mais aparecem nas Keywords do nosso presidente e também nos sumários.

# %%
texto = 'batatinha, quando, nasce, esparrama, pelo, chão'
texto = texto.split(',')
texto

# %%
texto = [x.strip() for x in texto]
texto

# %% [markdown]
# Expressões entre colchetes criam novas listas segundo o critério que está dentro, no caso acima, vamos fazer x.strip() para todo x dentro da lista texto

# %% [markdown]
# **Exercício**
#
# Repita o processo acima para outro Deputado Federal

# %% [markdown]
# Existem inúmeras APIs, podemos ver o que o Google completaria, dada uma expressão inicial

# %%
from requests import get
url = "http://suggestqueries.google.com/complete/search?client=firefox&q=Jair Bolsonaro é"
resp = get(url).json()
resp

# %% [markdown]
# **Exercício**
#
# Coloque outras frases a serem completadas para testar
